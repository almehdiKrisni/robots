# %% [markdown]
# En réunissant les fonctions et modélisations de tout les autres notebook, on crée une fonction allant nous permettre de nous approcher le plus possible de notre objectif étant la modélisation la plus générale et réaliste possible.
#
# On récupère dans un premier temps les fonctions liées à la partie économique puisqu'il serait incensé de vouloir créer un modèle réaliste sans avoir de rapport avec les capitaux et prix de robots.

# %%
import math
import random

def evolution_prix (robots_prix,nb_annees, min, max):
    liste_robots_prix = list()
    liste_robots_prix.append(robots_prix)
    
    i = 0
    while (i < nb_annees): 
        if (i<nb_annees//2):
            min = min + 0.001
            max = max + 0.001
            coef_random = random.uniform(min,max)
            liste_robots_prix.append(liste_robots_prix[i] - (liste_robots_prix[i])*coef_random//100)
            i = i + 1
        elif ( i >= nb_annees//2):
            min = min 
            max = max - 0.004
            coef_random = random.uniform(min,max)
            liste_robots_prix.append(liste_robots_prix[i] - (liste_robots_prix[i])*coef_random//100)
            i = i + 1
        
    return liste_robots_prix

# %%
liste = evolution_prix(120000,50, 0, 1.5)
print(liste)
# Out:
# [120000, 119210.0, 118706.0, 118270.0, 118164.0, 117698.0, 116437.0, 116031.0, 114583.0, 114109.0, 113756.0, 113391.0, 112107.0, 111018.0, 109349.0, 107871.0, 107755.0, 106870.0, 106492.0, 106409.0, 106053.0, 104473.0, 103485.0, 103098.0, 103013.0, 102596.0, 102337.0, 101838.0, 100954.0, 100301.0, 99371.0, 98445.0, 97339.0, 96911.0, 95560.0, 94517.0, 93741.0, 93449.0, 92400.0, 91481.0, 90408.0, 89158.0, 88650.0, 87848.0, 86674.0, 85966.0, 85622.0, 85556.0, 84638.0, 83601.0, 83261.0]

# %%
import matplotlib.pyplot as plt

liste = evolution_prix(120000,49,0,1.5)

plt.plot(liste)
plt.xlabel("Generation")
plt.ylabel("Prix d'un robot")
plt.show()

# %%
import random
def econmie_entreprise (budget_initial,prix_robots, nb_annees, demande, concurrents):
    
    min = 0
    max = 1
    var_demande = demande
    var_concurrents = concurrents
    i = 0
    liste_budget = list()
    liste_budget.append(budget_initial)
    budget = budget_initial
    frais = prix_robots/100*40
    
    while (i != nb_annees):
        proba_vente = random.uniform((min+var_demande-var_concurrents),(max+var_demande-var_concurrents))
        if (proba_vente > 0.5):
            budget = budget + prix_robots - frais
            liste_budget.append(budget)
        else:
            budget = budget - frais
            liste_budget.append(budget)
            
        i = i + 1
        
    return liste_budget

# %%
liste = econmie_entreprise(100000,100,100,0.23,0.35)
print(liste)
# Out:
# [100000, 99960.0, 100020.0, 100080.0, 100140.0, 100100.0, 100160.0, 100220.0, 100280.0, 100240.0, 100200.0, 100160.0, 100120.0, 100080.0, 100040.0, 100100.0, 100160.0, 100120.0, 100080.0, 100040.0, 100100.0, 100060.0, 100120.0, 100080.0, 100040.0, 100100.0, 100160.0, 100220.0, 100180.0, 100240.0, 100200.0, 100160.0, 100120.0, 100180.0, 100140.0, 100200.0, 100160.0, 100220.0, 100180.0, 100240.0, 100300.0, 100360.0, 100320.0, 100280.0, 100240.0, 100300.0, 100260.0, 100220.0, 100180.0, 100240.0, 100200.0, 100160.0, 100120.0, 100080.0, 100040.0, 100000.0, 99960.0, 99920.0, 99980.0, 99940.0, 100000.0, 99960.0, 100020.0, 99980.0, 99940.0, 99900.0, 99960.0, 100020.0, 99980.0, 99940.0, 99900.0, 99960.0, 99920.0, 99880.0, 99940.0, 99900.0, 99860.0, 99920.0, 99980.0, 100040.0, 100000.0, 100060.0, 100020.0, 100080.0, 100140.0, 100100.0, 100160.0, 100220.0, 100180.0, 100140.0, 100200.0, 100160.0, 100220.0, 100280.0, 100240.0, 100300.0, 100260.0, 100220.0, 100180.0, 100240.0, 100200.0]

# %%
import matplotlib.pyplot as plt

liste = econmie_entreprise(100000,10000,100,0.7,0.5)
plt.plot(liste)
plt.xlabel("Generation")
plt.ylabel("Budget")
plt.show()

# %%
import random
def econmie_entreprise_Final (budget_initial,prix_robots, nb_annees, demande, concurrents):
    
    min = 0
    max = 1
    var_demande = demande
    var_concurrents = concurrents
    var_prix_robots = prix_robots
    i = 0
    liste_budget = list()
    liste_budget.append(budget_initial)
    budget = budget_initial
    frais = prix_robots/100*30
    
    while (i != nb_annees):
        proba_vente = random.uniform((min+var_demande-var_concurrents),(max+var_demande-var_concurrents))
        if (proba_vente > 0.5):
            budget = budget + var_prix_robots - frais
            liste_budget.append(budget)
        else:
            budget = budget - frais
            liste_budget.append(budget)
            
        i = i + 1
        
        random_var = random.uniform(0,100)
        if random_var > 80:
            var_demande = var_demande + 0.02
        elif random_var < 20:
            var_concurrents = var_concurrents + 0.02
        elif random_var < 1:
            frais = frais - 0.3 * frais
        elif random_var < 1:
            var_demande = 0
            
        min1 = 0
        max1 = 1.5
            
        if (i<nb_annees//2):
            min1 = min1 + 0.001
            max1 = max1 + 0.001
            coef_random = random.uniform(min1,max1)
            var_prix_robots = var_prix_robots - var_prix_robots*coef_random//100
        elif (i >= nb_annees//2):
            min1 = min1
            max1 = max1 + 0.1
            coef_random = random.uniform(min1,max1)
            var_prix_robots = var_prix_robots - var_prix_robots*coef_random//100
            
    return liste_budget

# %%
import matplotlib.pyplot as plt

liste = econmie_entreprise_Final(100000,7000,100,0.5,0.5)
plt.plot(liste)
plt.xlabel("Generation")
plt.ylabel("Budget")
plt.show()

# %%
import random
def VoirDemande (budget_initial,prix_robots, nb_annees, demande, concurrents):
    
    min = 0
    max = 1
    var_demande = demande
    var_concurrents = concurrents
    var_prix_robots = prix_robots
    i = 0
    liste_budget = list()
    liste_budget.append(budget_initial)
    budget = budget_initial
    frais = prix_robots/100*30
    liste_demande = list()
    liste_concurrents = list()
    
    
    while (i != nb_annees):
        proba_vente = random.uniform((min+var_demande-var_concurrents),(max+var_demande-var_concurrents))
        if (proba_vente > 0.5):
            budget = budget + var_prix_robots - frais
            liste_budget.append(budget)
        else:
            budget = budget - frais
            liste_budget.append(budget)
            
        i = i + 1
        
        random_var = random.uniform(0,100)
        if random_var > 80:
            var_demande = var_demande + 0.02
        elif random_var < 20:
            var_concurrents = var_concurrents + 0.02
        elif random_var < 1:
            frais = frais - 0.3 * frais
            
        min1 = 0
        max1 = 1.5
            
        if (i<nb_annees//2):
            min1 = min1 + 0.001
            max1 = max1 + 0.001
            coef_random = random.uniform(min1,max1)
            var_prix_robots = var_prix_robots - var_prix_robots*coef_random//100
        elif (i >= nb_annees//2):
            min1 = min1
            max1 = max1 + 0.1
            coef_random = random.uniform(min1,max1)
            var_prix_robots = var_prix_robots - var_prix_robots*coef_random//100
        liste_demande.append(var_demande)
            
    return liste_demande

# %%
import matplotlib.pyplot as plt

liste = VoirDemande(100000,7000,100,0.5,0.5)
plt.plot(liste)
plt.xlabel("Génération")
plt.ylabel("Demande")
plt.show()

# %%
import random
def VoirConcurrents (budget_initial,prix_robots, nb_annees, demande, concurrents):
    
    min = 0
    max = 1
    var_demande = demande
    var_concurrents = concurrents
    var_prix_robots = prix_robots
    i = 0
    liste_budget = list()
    liste_budget.append(budget_initial)
    budget = budget_initial
    frais = prix_robots/100*30
    liste_demande = list()
    liste_concurrents = list()
    
    
    while (i != nb_annees):
        proba_vente = random.uniform((min+var_demande-var_concurrents),(max+var_demande-var_concurrents))
        if (proba_vente > 0.5):
            budget = budget + var_prix_robots - frais
            liste_budget.append(budget)
        else:
            budget = budget - frais
            liste_budget.append(budget)
            
        i = i + 1
        
        random_var = random.uniform(0,100)
        if random_var > 80:
            var_demande = var_demande + 0.02
        elif random_var < 20:
            var_concurrents = var_concurrents + 0.02
        elif random_var < 1:
            frais = frais - 0.3 * frais
            
        min1 = 0
        max1 = 1.5
            
        if (i<nb_annees//2):
            min1 = min1 + 0.001
            max1 = max1 + 0.001
            coef_random = random.uniform(min1,max1)
            var_prix_robots = var_prix_robots - var_prix_robots*coef_random//100
        elif (i >= nb_annees//2):
            min1 = min1
            max1 = max1 + 0.1
            coef_random = random.uniform(min1,max1)
            var_prix_robots = var_prix_robots - var_prix_robots*coef_random//100
        liste_concurrents.append(var_concurrents)
        
    return liste_concurrents

# %%
import matplotlib.pyplot as plt

liste = VoirConcurrents(100000,7000,100,0.5,0.5)
plt.plot(liste)
plt.xlabel("Generation")
plt.ylabel("Budget")
plt.show()

# %%
import random
def VoirProba (budget_initial,prix_robots, nb_annees, demande, concurrents):
    
    min = 0
    max = 1
    var_demande = demande
    var_concurrents = concurrents
    var_prix_robots = prix_robots
    i = 0
    liste_budget = list()
    liste_budget.append(budget_initial)
    budget = budget_initial
    frais = prix_robots/100*30
    liste_demande = list()
    liste_concurrents = list()
    liste_proba_vente = list()
    
    
    while (i != nb_annees):
        proba_vente = random.uniform((min+var_demande-var_concurrents),(max+var_demande-var_concurrents))
        if (proba_vente > 0.5):
            budget = budget + var_prix_robots - frais
            liste_budget.append(budget)
        else:
            budget = budget - frais
            liste_budget.append(budget)
            
        i = i + 1
        
        random_var = random.uniform(0,100)
        if random_var > 80:
            var_demande = var_demande + 0.02
        elif random_var < 20:
            var_concurrents = var_concurrents + 0.02
        elif random_var < 1:
            frais = frais - 0.3 * frais
            
        min1 = 0
        max1 = 1.5
            
        if (i<nb_annees//2):
            min1 = min1 + 0.001
            max1 = max1 + 0.001
            coef_random = random.uniform(min1,max1)
            var_prix_robots = var_prix_robots - var_prix_robots*coef_random//100
        elif (i >= nb_annees//2):
            min1 = min1
            max1 = max1 + 0.1
            coef_random = random.uniform(min1,max1)
            var_prix_robots = var_prix_robots - var_prix_robots*coef_random//100
        liste_proba_vente.append(proba_vente)
            
    return liste_proba_vente

# %%
import matplotlib.pyplot as plt

liste = VoirProba(100000,7000,100,0.5,0.5)
plt.plot(liste)
plt.xlabel("Generation")
plt.ylabel("Probabilité de vendre le robot")
plt.show()

# %%
import random
def econmie_entreprise_Final_Marketing (budget_initial,prix_robots, nb_annees, demande, concurrents):
    
    min = 0
    max = 1
    var_demande = demande
    var_concurrents = concurrents
    var_prix_robots = prix_robots
    i = 0
    liste_budget = list()
    liste_budget.append(budget_initial)
    budget = budget_initial
    frais_marketing = var_prix_robots//10
    frais = prix_robots/100*30 + frais_marketing
    liste_demande = list()
    liste_concurrents = list()
    
    
    while (i != nb_annees):
        proba_vente = random.uniform((min+var_demande-var_concurrents),(max+var_demande-var_concurrents))
        if (proba_vente > 0.5):
            budget = budget + var_prix_robots - frais
            liste_budget.append(budget)
        else:
            budget = budget - frais
            liste_budget.append(budget)
            
        i = i + 1
        
        random_var = random.uniform(0,100)
        if random_var > 80:
            var_demande = var_demande + 0.02
        elif random_var < 20:
            var_concurrents = var_concurrents + 0.02
        elif random_var < 1:
            frais = frais - 0.3 * frais
            
        min1 = 0
        max1 = 1.5
            
        if (i<nb_annees//2):
            min1 = min1 + 0.001
            max1 = max1 + 0.001
            coef_random = random.uniform(min1,max1)
            var_prix_robots = var_prix_robots - var_prix_robots*coef_random//100
        elif (i >= nb_annees//2):
            min1 = min1
            max1 = max1 + 0.1
            coef_random = random.uniform(min1,max1)
            var_prix_robots = var_prix_robots - var_prix_robots*coef_random//100
            
        if (proba_vente < 0.5):
            frais_marketing = frais_marketing + var_prix_robots//100
            var_demande = var_demande + 0.01
            
    return liste_budget

# %%
import matplotlib.pyplot as plt

liste = econmie_entreprise_Final_Marketing(100000,7000,100,0.5,0.5)
plt.plot(liste)
plt.xlabel("Generation")
plt.ylabel("Capital")
plt.show()

# %% [markdown]
# Désormais, on s'active à la création de la fonction finale.

# %%
def master_fonction () :
